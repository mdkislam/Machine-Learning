# %% [markdown]
# <a href="https://colab.research.google.com/github/mdkislam/Machine-Learning/blob/main/HR_Analytics_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the dataset
attrition_data = "https://raw.githubusercontent.com/mdkislam/data/main/Hr_Attrition%20analysis.csv"
satisfaction_evaluation_data = "https://github.com/mdkislam/data/blob/main/employee_satisfaction_evaluation.xlsx?raw=true"

# %%
df1 = pd.read_csv(attrition_data)
df2 = pd.read_excel(satisfaction_evaluation_data)

# %%
df1.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
df2.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
df1.shape,df2.shape
# Out:
# ((14999, 9), (14999, 3))

# %%
df1.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['EMPLOYEE #', 'satisfaction_level', 'last_evaluation'], dtype='object')

# %% [markdown]
# `df1['employee_id']` and `df2['EMPLOYEE #']` are identical we can join both dataframe with the help of these.

# %% [markdown]
# ## Join both the tables

# %%
df = df1.set_index('employee_id').join(df2.set_index('EMPLOYEE #'))

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary  \
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low
#
#    satisfaction_level  last_evaluation
# 0                0.38             0.53
# 1                0.80             0.86
# ...

# %%
# List out all the categorical data
not_num_col = df.select_dtypes(include='object').columns.tolist()
not_num_col
# Out:
# ['department', 'salary']

# %%
# Treat all the feature as categorical features which have less than or equal to 10 number of categories
# create a list of all those feature
cat_col = df.nunique()[df.nunique()<=10].index.tolist()
cat_col
# Out:
# ['number_project',
#  'time_spend_company',
#  'Work_accident',
#  'left',
#  'promotion_last_5years',
#  'department',
#  'salary']

# %%
# check all the columns with missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
# check for missing data in the form of all data
temp = df[df.isnull().any(axis=1)]
temp
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# ...

# %%
# Both the columns are numeric type so I can replace missing values with mean of the data
# get statistical summery of the data
df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# ...

# %%
df[df.satisfaction_level>df.satisfaction_level.mean()]['number_project',]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 1             1005               5                   262                   6
# 3             1038               5                   223                   5
# 7             1576               5                   259                   5
# 8             1752               5                   224                   5
# 12            2040               4                   234                   5
# ...            ...             ...                   ...                 ...
# 14985        87624               5                   254                   5
# 14986        87625               4                   247                   6
# 14987        87632               5                   206                   4
# 14990        87639               5                   228                   5
# 14993        87661               6                   293                   6
#
# ...
